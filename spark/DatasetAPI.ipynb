// %%
import org.apache.spark.sql.SparkSession
// Out:
// Intitializing Scala interpreter ...

// %%
//TODO Illustrate how this fails if you change from Option[String] to String for referrer

val sparkSession = SparkSession.builder
        .appName("Jupyter").getOrCreate()

// %% [markdown]
// ## What this does:
//
// - Builds a Spark application
// - Sets the app name to `Juptyer` (just a label you’ll see in Spark UI)
// - `getOrCreate()`:
//    - Reuses an existing Spark session if one exists
//    - Otherwise creates a new one
//
// 👉 This is **standard Spark boilerplate.**

// %%
1 + 1
// Out:
// Intitializing Scala interpreter ...
